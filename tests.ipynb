# %% [markdown]
# <a href="https://colab.research.google.com/github/ptejaswi528/EDA/blob/main/tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df=sns.load_dataset('taxis')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
((df.shape[0]-df.dropna().shape[0])*100)
# Out:
# 0

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.reset_index()
# Out:
#       index              pickup             dropoff  passengers  distance  \
# 0         0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60
# 1         1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79
# 2         2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37
# 3         3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70
# 4         4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16
# ...     ...                 ...                 ...         ...       ...
# 6336   6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75
# 6337   6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74
# 6338   6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14
# 6339   6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12
# 6340   6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85
#
#       fare   tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
sns.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.color,kde=True,palette={'grey','pink'})
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
import seaborn as sns
df=sns.load_dataset('taxis')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
sns.histplot(x=df.tip,hue=df.payment,kde=True,palette={'grey','pink'})
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
#payment vs tip
credit_tip=df['tip'][df['payment']=='credit card']
cash_tip=df['tip'][df['payment']=='cash']
from scipy import stats
t_stat,p_val=stats.ttest_ind(credit_tip,cash_tip)
print("independent T-Test statistic:",t_stat)
print("p-value:",p_val)
alpha=0.05

if(p_val<alpha):
    print("Reject null hypothesis: The tip for credit card payment is different from cash")
else:
    print("Fail to reject null hypothesis")
# Out:
# independent T-Test statistic: 47.5771244729178
# p-value: 0.0
# Reject null hypothesis: The tip for credit card payment is different from cash

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', nan, 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5268
# Queens        657
# Brooklyn      383
# Bronx          99
# Name: count, dtype: int64

# %%
yellow_tip=df['tip'][df['color']=='yellow']
green_tip=df['tip'][df['color']=='green']

# %%
green_tip.shape
# Out:
# (968,)

# %%
from scipy import stats
t_stat,p_val=stats.ttest_ind(yellow_tip,green_tip)
print("independent T-Test statistic:",t_stat)
print("p-value:",p_val)
# Out:
# independent T-Test statistic: 17.05932566128597
# p-value: 7.791088119489451e-64

# %%
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %%
sns.barplot(x=df['pickup_borough'])
# Out:
# <Axes: xlabel='pickup_borough'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.966345
# Manhattan    1.939550
# Queens       3.040061
# Name: tip, dtype: float64

# %%
sns.histplot(x=df['tip'],hue=df['pickup_borough'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# H0: distribution of tip is same across all pickup_borough categories
#
# H1: At least one category has a different distribution of tip

# %%
manhattan_tip=df['tip'][df['pickup_borough']=='Manhattan']
queens_tip=df['tip'][df['pickup_borough']=='Queens']
bronx_tip=df['tip'][df['pickup_borough']=='Bronx']
brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']


#regions=[group['Spending_Score'].values for name,group in df.groupby('pickup_borough')]

f_stat,p_val=stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip)
#print("ANOVA F-statistics:", f_stat
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothese:")
# Out:
# P-value: 1.20915798251319e-56
# Reject null hypothesis:

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey=pairwise_tukeyhsd(endog=df['tip'],groups=df['pickup_borough'],alpha=0.05)
print(tukey)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
manhattan_tip=df['tip'][df['dropoff_borough']=='Manhattan']
queens_tip=df['tip'][df['dropoff_borough']=='Queens']
bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
staten_tip=df['tip'][df['dropoff_borough']=='Staten Island']

#regions=[group['Spending_Score'].values for name,group in df.groupby('pickup_borough')]

f_stat,p_val=stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip,staten_tip)
print("ANOVA F-statistics:", f_stat)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothese:")
# Out:
# ANOVA F-statistics: 31.42417796696829
# P-value: 5.87859571331583e-26
# Reject null hypothesis:

# %%
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd

df_tukey = df[['tip', 'pickup_borough']].copy()

# Force correct types
df_tukey['tip'] = pd.to_numeric(df_tukey['tip'], errors='coerce')
df_tukey['pickup_borough'] = df_tukey['pickup_borough'].astype(str)

# Remove invalid rows
df_tukey = df_tukey.dropna()

# Remove empty strings if any
df_tukey = df_tukey[df_tukey['pickup_borough'].str.strip() != ""]

# Reset index
df_tukey.reset_index(drop=True, inplace=True)

# Tukey test
tukey = pairwise_tukeyhsd(
    endog=df_tukey['tip'].values,
    groups=df_tukey['pickup_borough'].values,
    alpha=0.05
)

print(tukey)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'],palette='Set2',estimator='mean')
# Out:
# /tmp/ipython-input-3379706018.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'],palette='Set2',estimator='mean')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'],palette='Set2',estimator='std')
# Out:
# /tmp/ipython-input-3124366551.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'],palette='Set2',estimator='std')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'],palette='Set2',estimator='mean')
# Out:
# /tmp/ipython-input-1907679131.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'],palette='Set2',estimator='mean')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.countplot(x=df['dropoff_borough'],palette='Set1')
# Out:
# /tmp/ipython-input-527273607.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'],palette='Set1')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.histplot(x=df['tip'],hue=df['dropoff_borough'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
from scipy.stats import pearsonr,     spearmanr
                       #normal data   #outliers skew data

# %%
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("correlation: ",r)
print("P-value: ",p_val)
alpha=0.05
if p_val<alpha:
  print("Reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# correlation:  0.027509812818779178
# P-value:  0.028480753176042872
# Reject null hypothesis

# %%
nm=df[['fare','tip','tolls','distance','passengers']]

# %%
sns.heatmap(nm.corr(),annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
sns.histplot(df['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.scatterplot(x=df.tip,y=df.tolls)
# Out:
# <Axes: xlabel='tip', ylabel='tolls'>

# %%
sns.barplot(x=df['tip'], y=df['distance'])
# Out:
# <Axes: xlabel='tip', ylabel='distance'>

# %%
import seaborn as sns
df = sns.load_dataset('taxis')
df = df.dropna()
sns.histplot(x=df['distance'], kde=True)
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
from scipy.stats import spearmanr

r_spearman, p_value_spearman = spearmanr(df['tip'], df['distance'])

print(f"Spearman's correlation coefficient between tip and distance: {r_spearman:.4f}")
print(f"P-value: {p_value_spearman:.4f}")

alpha = 0.05
if p_value_spearman < alpha:
    print("Result: Reject the null hypothesis. There is a statistically significant monotonic relationship between tip and distance.")
else:
    print("Result: Fail to reject the null hypothesis. There is no statistically significant monotonic relationship between tip and distance.")
# Out:
# Spearman's correlation coefficient between tip and distance: 0.2927
# P-value: 0.0000
# Result: Reject the null hypothesis. There is a statistically significant monotonic relationship between tip and distance.

# %%
sns.scatterplot(x=df['distance'], y=df['tip'])
# Out:
# <Axes: xlabel='distance', ylabel='tip'>

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_dayname']=df['dropoff'].dt.day_name()
df['dropoff_hour']=df['dropoff'].dt.hour
df['dropoff_minute']=df['dropoff'].dt.minute
df['dropoff_second']=df['dropoff'].dt.second
df['dropoff_day']=df['dropoff'].dt.day

# %%
df.shape
# Out:
# (6341, 21)

# %%
r,p_val=stats.spearmanr(df['tip'],df['dropoff_dayname'])
print("correlation:",r)
alpha=0.05
if p_val<alpha:
  print("Reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# correlation: 0.027779265329806905
# Reject null hypothesis

# %%
df['pickup_dayname'] = df['pickup'].dt.day_name()

df['pickup_month'] = df['pickup'].dt.month_name()

df['pickup_quarter'] = df['pickup'].dt.quarter

df['pickup_year'] = df['pickup'].dt.year

df['pickup_hour'] = df['pickup'].dt.hour
df['pickup_second']=df['pickup'].dt.second
df['pickup_minute']=df['pickup'].dt.minute
df['pickup_day']=df['pickup'].dt.day

# %%
r,p_val=stats.spearmanr(df['tip'],df['pickup_dayname'])
print("correlation:",r)
alpha=0.05
if p_val<alpha:
  print("Reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# correlation: 0.026695959763010802
# Reject null hypothesis

# %%
my_drop_list = [
    'pickup_month','pickup_day','pickup_year','pickup_second','pickup_minute','pickup_quarter','dropoff_month','dropoff_year','dropoff_day','dropoff_minute','dropoff_second','dropoff_quarter','pickup','dropoff']
existing_columns_to_drop = [col for col in my_drop_list if col in df.columns]
if existing_columns_to_drop:

    df = df.drop(columns=existing_columns_to_drop) # Modify df directly

    print(f"Successfully dropped columns: {existing_columns_to_drop}")
    print("\nFirst 5 rows of the DataFrame after dropping columns:")
    display(df.head())

# %%
datetime_cols = [
    'pickup_datetime',
    'dropoff_datetime'
]

# %%
x_train = x_train.drop(columns=datetime_cols, errors='ignore')
x_test  = x_test.drop(columns=datetime_cols, errors='ignore')

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# The columns pickup_month, dropoff_month, pickup_day are dropped or are already numeric
cat=['color','payment','pickup_zone','dropoff_zone','pickup_borough','dropoff_borough','pickup_dayname','dropoff_dayname']
for i in cat:
    df[i]=lb.fit_transform(df[i])


df.head()
# Out:
#    passengers  distance      fare   tip     tolls     total  color  payment  \
# 0           1 -0.375780 -0.549175  2.15 -0.229932 -0.413941      1        1
# 1           1 -0.593552 -0.735718  0.00 -0.229932 -0.695808      1        0
# 2           1 -0.437617 -0.502540  2.36 -0.229932 -0.320500      1        1
# 3           1  1.264233  1.316252  6.15 -0.229932  1.439435      1        1
# 4           3 -0.225221 -0.362633  1.10 -0.229932 -0.379190      1        1
#
#    pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  \
# 0           99           176               2                2
# 1          174           182               2                2
# 2            1           190               2                2
# 3           86           202               2                2
# 4          116           202               2                2
#
#    dropoff_dayname  dropoff_hour  pickup_hour  pickup_dayname
# 0                2            20           20               2
# ...

# %%
datetime_cols = x_train.select_dtypes(include=['datetime64[ns]']).columns

# %%
x_train = x_train.drop(columns=datetime_cols)
x_test  = x_test.drop(columns=datetime_cols)

# %%
cont=['fare','tolls','total','distance']
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df[cont]=st.fit_transform(df[cont])

# %%
x = df.drop(['tip'], axis=1)
y = df.tip

# %%
print(x.shape)
print(y.shape)
# Out:
# (6341, 15)
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
print('X train shape : ',x_train.shape)
print('X test shape : ',x_test.shape)
print('Y train shape : ',y_train.shape)
print('Y test shape : ',y_test.shape)
# Out:
# X train shape :  (4755, 15)
# X test shape :  (1586, 15)
# Y train shape :  (4755,)
# Y test shape :  (1586,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Model Intercept:', model.intercept_)
# Out:
# Model Intercept: 2.7654263362804796

# %%
y_train_pred=model.predict(x_train)
train_score=model.score(x_train,y_train)
print('Training score : ',train_score)
# Out:
# Training score :  0.9226629288855469

# %%
y_test_pred=model.predict(x_test)
test_score=model.score(x_test,y_test)
print('Testing score : ',test_score)
# Out:
# Testing score :  0.928503515071117

# %%
from sklearn.metrics import mean_squared_error,root_mean_squared_error,mean_absolute_error,r2_score

# %%
rmse_train = root_mean_squared_error(y_train,y_train_pred)
print('Training RMSE:', rmse_train)
# Out:
# Training RMSE: 0.653685187811413

# %%
mse_train = mean_squared_error(y_train,y_train_pred)
print('Training MSE:', mse_train)
# Out:
# Training MSE: 0.4273043247640424

# %%
mae_train = mean_absolute_error(y_train,y_train_pred)
print('Training MAE:', mae_train)
# Out:
# Training MAE: 0.43486633401228314

# %%
rmse_test = root_mean_squared_error(y_test,y_test_pred)
print('Testing RMSE:', rmse_test)
mse_test = mean_squared_error(y_test,y_test_pred)
print('Testing MSE:', mse_test)
mae_test = mean_absolute_error(y_test,y_test_pred)
print('Testing MAE:', mae_test)
# Out:
# Testing RMSE: 0.6401916614426637
# Testing MSE: 0.4098453633807182
# Testing MAE: 0.4356441966531355

# %%
model.intercept_
# Out:
# np.float64(2.7654263362804796)

# %%
y_train_pred=model.predict(x_train)
train_score=model.score(x_train,y_train)
print('Training score : ',train_score)
# Out:
# Training score :  0.9226629288855469

# %%
y_test_pred=model.predict(x_test)
test_score=model.score(x_test,y_test)
print('Testing score : ',test_score)

# %%
from sklearn.metrics import mean_squared_error,root_mean_squared_error,mean_absolute_error,r2_score

# %%
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.653685187811413

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 0.4273043247640424

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.43486633401228314
